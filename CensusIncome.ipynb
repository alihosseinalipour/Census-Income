# %% [markdown]
# For downloading dataset:
#
# https://archive.ics.uci.edu/dataset/2/adult

# %% [markdown]
# * Dataset Information
# Prediction task is to determine whether a person makes over 50K a year.
#
# * Has Missing Values? Yes

# %% [markdown]
# ### Listing of attributes:
#
# age: continuous.
#
# workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
#
# fnlwgt: continuous.
#
# education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
#
# education-num: continuous.
#
# marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
#
# occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
#
# relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
#
# race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
#
# sex: Female, Male.
# capital-gain: continuous.
#
# capital-loss: continuous.
#
# hours-per-week: continuous.
#
# native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
col=['age','workclass','fnlwgt','education', 'education-num' ,'marital-status'
     ,'occupation','relationship','race','sex','capital-gain','capital-loss'
     ,'hours-per-week','native-country', 'income']

# %%
data= pd.read_csv('adult.csv', names = col)

# %%
data.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
data.shape
# Out:
# (32561, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
data.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# # EDA

# %% [markdown]
# ### Handeling messing values

# %%
data.isin([' ?']).sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# income               0
# dtype: int64

# %%
data.drop(data[data['native-country']==' ?'].index , inplace=True)
data.drop(data[data['occupation']==' ?'].index , inplace=True)

# %%
sns.heatmap(data.isin([' ?']),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
data.isin([' ?']).sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# income            0
# dtype: int64

# %% [markdown]
# ## Handeling non-numeric columns

# %%
dummies_income = pd.get_dummies(data.income , drop_first=True)
dummies_sex = pd.get_dummies(data.sex , drop_first=True)
dummies_race = pd.get_dummies(data.race , drop_first=True)
data = pd.concat([data.drop(['income', 'sex' , 'race'] , axis=1) , dummies_sex, dummies_race, dummies_income], axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
data['workclass']= encoder.fit_transform(data['workclass'])
data['education']= encoder.fit_transform(data['education'])
data['marital-status']= encoder.fit_transform(data['marital-status'])
data['occupation']= encoder.fit_transform(data['occupation'])
data['relationship']= encoder.fit_transform(data['relationship'])
data['native-country']= encoder.fit_transform(data['native-country'])

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr() , annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Balancing data set

# %%
from imblearn.over_sampling import RandomOverSampler
os = RandomOverSampler(random_state=42)

# %%
X = data.drop(' >50K' , axis=1)
Y = data[' >50K']

# %%
X_os , Y_os = os.fit_resample(X,Y)

# %%
data_os = pd.concat([X_os , Y_os] ,axis=1)

# %%
sns.barplot(x= data_os[' >50K'].value_counts().index , y=data_os[' >50K'].value_counts())
# Out:
# <AxesSubplot:ylabel=' >50K'>

# %% [markdown]
# ## Train test set split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_os, Y_os, test_size=0.1, random_state=42)

# %% [markdown]
# ## Normalization

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler()

X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Crearing Learning Models

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.utils import plot_model
from tensorflow.keras.callbacks import EarlyStopping , ModelCheckpoint
import tensorflow as tf

# %%
num_features = len(X_train[0])

# %%
early_stopping = EarlyStopping(monitor='val_loss' , mode='min' , patience=20 , verbose=1)

checkpoint_filepath = 'weights.h5'
check_point = ModelCheckpoint(filepath=checkpoint_filepath,monitor='val_accuracy', mode='max', save_best_only=True)

# %%
model_nn = Sequential()

model_nn.add(Input(shape=(X_train.shape[1],)))

model_nn.add(Dense(num_features , activation='relu'))
model_nn.add(Dropout(0.5))

model_nn.add(Dense(20 , activation='relu'))
model_nn.add(Dropout(0.5))

model_nn.add(Dense(20 , activation='relu'))
model_nn.add(Dropout(0.5))

model_nn.add(Dense(1 , activation='sigmoid'))

model_nn.compile(loss='binary_crossentropy',
                 optimizer = 'adam',
                 metrics= 'accuracy')

# %%
model_nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 17)                306
#
#  dropout_3 (Dropout)         (None, 17)                0
#
#  dense_5 (Dense)             (None, 20)                360
#
#  dropout_4 (Dropout)         (None, 20)                0
#
#  dense_6 (Dense)             (None, 20)                420
#
#  dropout_5 (Dropout)         (None, 20)                0
#
#  dense_7 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 1,107
# Trainable params: 1,107
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model_nn)

# %%
model_nn.fit(X_train,y_train,
             epochs=250,
             batch_size= 256,
             validation_split = 0.1,
             callbacks=[early_stopping, check_point])
# Out:
# Epoch 1/250
# 144/144 [==============================] - 3s 9ms/step - loss: 0.6799 - accuracy: 0.5537 - val_loss: 0.6450 - val_accuracy: 0.6731
# Epoch 2/250
# 144/144 [==============================] - 1s 8ms/step - loss: 0.6433 - accuracy: 0.6418 - val_loss: 0.5921 - val_accuracy: 0.7151
# Epoch 3/250
# 144/144 [==============================] - 1s 8ms/step - loss: 0.6071 - accuracy: 0.6815 - val_loss: 0.5527 - val_accuracy: 0.7305
# Epoch 4/250
# 144/144 [==============================] - 2s 12ms/step - loss: 0.5855 - accuracy: 0.7021 - val_loss: 0.5245 - val_accuracy: 0.7384
# Epoch 5/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.5623 - accuracy: 0.7150 - val_loss: 0.4971 - val_accuracy: 0.7670
# Epoch 6/250
# 144/144 [==============================] - 1s 7ms/step - loss: 0.5429 - accuracy: 0.7319 - val_loss: 0.4773 - val_accuracy: 0.7845
# Epoch 7/250
# 144/144 [==============================] - 1s 8ms/step - loss: 0.5312 - accuracy: 0.7376 - val_loss: 0.4625 - val_accuracy: 0.7960
# Epoch 8/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.5229 - accuracy: 0.7427 - val_loss: 0.4564 - val_accuracy: 0.7935
# Epoch 9/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.5164 - accuracy: 0.7532 - val_loss: 0.4437 - val_accuracy: 0.8053
# Epoch 10/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.5057 - accuracy: 0.7606 - val_loss: 0.4420 - val_accuracy: 0.7992
# Epoch 11/250
# 144/144 [==============================] - 1s 10ms/step - loss: 0.4987 - accuracy: 0.7632 - val_loss: 0.4333 - val_accuracy: 0.8033
# Epoch 12/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4946 - accuracy: 0.7652 - val_loss: 0.4280 - val_accuracy: 0.8038
# Epoch 13/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4917 - accuracy: 0.7657 - val_loss: 0.4279 - val_accuracy: 0.8046
# Epoch 14/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4899 - accuracy: 0.7679 - val_loss: 0.4253 - val_accuracy: 0.8065
# Epoch 15/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4860 - accuracy: 0.7717 - val_loss: 0.4227 - val_accuracy: 0.8058
# Epoch 16/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4845 - accuracy: 0.7727 - val_loss: 0.4192 - val_accuracy: 0.8077
# Epoch 17/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4774 - accuracy: 0.7765 - val_loss: 0.4173 - val_accuracy: 0.8100
# Epoch 18/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4784 - accuracy: 0.7753 - val_loss: 0.4170 - val_accuracy: 0.8080
# Epoch 19/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4748 - accuracy: 0.7794 - val_loss: 0.4170 - val_accuracy: 0.8097
# Epoch 20/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4760 - accuracy: 0.7746 - val_loss: 0.4151 - val_accuracy: 0.8092
# Epoch 21/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4717 - accuracy: 0.7779 - val_loss: 0.4080 - val_accuracy: 0.8082
# Epoch 22/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4741 - accuracy: 0.7785 - val_loss: 0.4131 - val_accuracy: 0.8092
# Epoch 23/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4746 - accuracy: 0.7788 - val_loss: 0.4135 - val_accuracy: 0.8122
# Epoch 24/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4677 - accuracy: 0.7825 - val_loss: 0.4111 - val_accuracy: 0.8114
# Epoch 25/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4717 - accuracy: 0.7789 - val_loss: 0.4127 - val_accuracy: 0.8102
# Epoch 26/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4673 - accuracy: 0.7809 - val_loss: 0.4119 - val_accuracy: 0.8095
# Epoch 27/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4669 - accuracy: 0.7814 - val_loss: 0.4104 - val_accuracy: 0.8109
# Epoch 28/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4655 - accuracy: 0.7804 - val_loss: 0.4155 - val_accuracy: 0.8070
# Epoch 29/250
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4653 - accuracy: 0.7799 - val_loss: 0.4087 - val_accuracy: 0.8112
# Epoch 30/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4622 - accuracy: 0.7818 - val_loss: 0.4097 - val_accuracy: 0.8102
# Epoch 31/250
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4628 - accuracy: 0.7804 - val_loss: 0.4088 - val_accuracy: 0.8146
# Epoch 32/250
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4646 - accuracy: 0.7826 - val_loss: 0.4099 - val_accuracy: 0.8109
# Epoch 33/250
# 144/144 [==============================] - 1s 8ms/step - loss: 0.4640 - accuracy: 0.7835 - val_loss: 0.4098 - val_accuracy: 0.8124
# Epoch 34/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4623 - accuracy: 0.7856 - val_loss: 0.4104 - val_accuracy: 0.8077
# Epoch 35/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4630 - accuracy: 0.7849 - val_loss: 0.4096 - val_accuracy: 0.8100
# Epoch 36/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4623 - accuracy: 0.7847 - val_loss: 0.4083 - val_accuracy: 0.8119
# Epoch 37/250
# 144/144 [==============================] - 0s 3ms/step - loss: 0.4595 - accuracy: 0.7852 - val_loss: 0.4081 - val_accuracy: 0.8092
# Epoch 38/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4605 - accuracy: 0.7876 - val_loss: 0.4079 - val_accuracy: 0.8124
# Epoch 39/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4603 - accuracy: 0.7861 - val_loss: 0.4058 - val_accuracy: 0.8149
# Epoch 40/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4578 - accuracy: 0.7884 - val_loss: 0.4059 - val_accuracy: 0.8144
# Epoch 41/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4592 - accuracy: 0.7882 - val_loss: 0.4070 - val_accuracy: 0.8104
# Epoch 42/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4605 - accuracy: 0.7898 - val_loss: 0.4075 - val_accuracy: 0.8097
# Epoch 43/250
# 144/144 [==============================] - 1s 3ms/step - loss: 0.4576 - accuracy: 0.7871 - val_loss: 0.4058 - val_accuracy: 0.8119
# Epoch 44/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4594 - accuracy: 0.7859 - val_loss: 0.4043 - val_accuracy: 0.8136
# Epoch 45/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4559 - accuracy: 0.7891 - val_loss: 0.4052 - val_accuracy: 0.8129
# Epoch 46/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4560 - accuracy: 0.7900 - val_loss: 0.4077 - val_accuracy: 0.8090
# Epoch 47/250
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4568 - accuracy: 0.7885 - val_loss: 0.4059 - val_accuracy: 0.8122
# Epoch 48/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4572 - accuracy: 0.7878 - val_loss: 0.4049 - val_accuracy: 0.8163
# Epoch 49/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4563 - accuracy: 0.7886 - val_loss: 0.4046 - val_accuracy: 0.8090
# Epoch 50/250
# 144/144 [==============================] - 1s 6ms/step - loss: 0.4563 - accuracy: 0.7871 - val_loss: 0.4032 - val_accuracy: 0.8154
# Epoch 51/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4548 - accuracy: 0.7892 - val_loss: 0.4059 - val_accuracy: 0.8119
# Epoch 52/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4584 - accuracy: 0.7899 - val_loss: 0.4065 - val_accuracy: 0.8112
# Epoch 53/250
# 144/144 [==============================] - 1s 3ms/step - loss: 0.4548 - accuracy: 0.7903 - val_loss: 0.4061 - val_accuracy: 0.8141
# Epoch 54/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4535 - accuracy: 0.7897 - val_loss: 0.4059 - val_accuracy: 0.8124
# Epoch 55/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4545 - accuracy: 0.7885 - val_loss: 0.4043 - val_accuracy: 0.8131
# Epoch 56/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4524 - accuracy: 0.7894 - val_loss: 0.4054 - val_accuracy: 0.8112
# Epoch 57/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4528 - accuracy: 0.7906 - val_loss: 0.4047 - val_accuracy: 0.8114
# Epoch 58/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4582 - accuracy: 0.7865 - val_loss: 0.4029 - val_accuracy: 0.8127
# Epoch 59/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4565 - accuracy: 0.7884 - val_loss: 0.4044 - val_accuracy: 0.8085
# Epoch 60/250
# 144/144 [==============================] - 1s 8ms/step - loss: 0.4543 - accuracy: 0.7894 - val_loss: 0.4042 - val_accuracy: 0.8134
# Epoch 61/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4555 - accuracy: 0.7925 - val_loss: 0.4024 - val_accuracy: 0.8136
# Epoch 62/250
# 144/144 [==============================] - 2s 13ms/step - loss: 0.4524 - accuracy: 0.7905 - val_loss: 0.4046 - val_accuracy: 0.8151
# Epoch 63/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4536 - accuracy: 0.7896 - val_loss: 0.4012 - val_accuracy: 0.8124
# Epoch 64/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4560 - accuracy: 0.7871 - val_loss: 0.4075 - val_accuracy: 0.8080
# Epoch 65/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4541 - accuracy: 0.7904 - val_loss: 0.4030 - val_accuracy: 0.8131
# Epoch 66/250
# 144/144 [==============================] - 0s 3ms/step - loss: 0.4562 - accuracy: 0.7897 - val_loss: 0.4052 - val_accuracy: 0.8129
# Epoch 67/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4534 - accuracy: 0.7904 - val_loss: 0.4092 - val_accuracy: 0.8092
# Epoch 68/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4540 - accuracy: 0.7880 - val_loss: 0.4067 - val_accuracy: 0.8124
# Epoch 69/250
# 144/144 [==============================] - 1s 7ms/step - loss: 0.4535 - accuracy: 0.7880 - val_loss: 0.4041 - val_accuracy: 0.8144
# Epoch 70/250
# 144/144 [==============================] - 0s 3ms/step - loss: 0.4540 - accuracy: 0.7933 - val_loss: 0.4058 - val_accuracy: 0.8154
# Epoch 71/250
# 144/144 [==============================] - 1s 3ms/step - loss: 0.4547 - accuracy: 0.7925 - val_loss: 0.4041 - val_accuracy: 0.8151
# Epoch 72/250
# 144/144 [==============================] - 1s 3ms/step - loss: 0.4495 - accuracy: 0.7960 - val_loss: 0.4062 - val_accuracy: 0.8080
# Epoch 73/250
# 144/144 [==============================] - 1s 3ms/step - loss: 0.4497 - accuracy: 0.7954 - val_loss: 0.4080 - val_accuracy: 0.8109
# Epoch 74/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4558 - accuracy: 0.7908 - val_loss: 0.4069 - val_accuracy: 0.8117
# Epoch 75/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4556 - accuracy: 0.7916 - val_loss: 0.4053 - val_accuracy: 0.8124
# Epoch 76/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4498 - accuracy: 0.7959 - val_loss: 0.4089 - val_accuracy: 0.8122
# Epoch 77/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4518 - accuracy: 0.7922 - val_loss: 0.4037 - val_accuracy: 0.8144
# Epoch 78/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4482 - accuracy: 0.7933 - val_loss: 0.4027 - val_accuracy: 0.8107
# Epoch 79/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4511 - accuracy: 0.7936 - val_loss: 0.4055 - val_accuracy: 0.8146
# Epoch 80/250
# 144/144 [==============================] - 1s 4ms/step - loss: 0.4509 - accuracy: 0.7934 - val_loss: 0.4020 - val_accuracy: 0.8131
# Epoch 81/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4548 - accuracy: 0.7947 - val_loss: 0.4077 - val_accuracy: 0.8173
# Epoch 82/250
# 144/144 [==============================] - 1s 5ms/step - loss: 0.4526 - accuracy: 0.7919 - val_loss: 0.4089 - val_accuracy: 0.8129
# Epoch 83/250
# 144/144 [==============================] - 1s 3ms/step - loss: 0.4527 - accuracy: 0.7948 - val_loss: 0.4066 - val_accuracy: 0.8104
# Epoch 83: early stopping

# %%
fig, axe = plt.subplots(1,2 , figsize=(10,5))
fig.tight_layout(pad=5.0)

axe[0].plot(model_nn.history.history['loss'], label='loss')
axe[0].plot(model_nn.history.history['val_loss'] , label='val_loss')
axe[1].plot(model_nn.history.history['accuracy'], label='accuracy')
axe[1].plot(model_nn.history.history['val_accuracy'] , label='val_accuracy')

axe[0].set_ylabel('Loss')
axe[0].set_xlabel('Epoch')
axe[1].set_ylabel('Accuracy')
axe[1].set_xlabel('Epoch')

axe[0].legend()
axe[1].legend()


# Or use the following lines:
#model_loss = pd.DataFrame(model_nn.history.history)
#model_loss.plot()

# %%
model_nn.load_weights('weights.h5')

# %%
predictions_nn = (model_nn.predict(X_test)>0.5).astype(int)
# Out:
# 142/142 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import confusion_matrix , classification_report

# %%
print(confusion_matrix(y_test, predictions_nn))
# Out:
# [[1741  573]
#  [ 272 1945]]

# %%
print(classification_report(y_test,predictions_nn ))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80      2314
#            1       0.77      0.88      0.82      2217
#
#     accuracy                           0.81      4531
#    macro avg       0.82      0.81      0.81      4531
# weighted avg       0.82      0.81      0.81      4531

# %%
acc_nn = classification_report(y_test,predictions_nn , output_dict=True)['accuracy']
acc_nn
# Out:
# 0.8135069521077025

# %% [markdown]
# ### SVC

# %%
from sklearn.svm import SVC

# %%
model_svc = SVC()

# %%
model_svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
predictions_svc = model_svc.predict(X_test)

# %%
acc_svc = classification_report(y_test,predictions_svc , output_dict=True)['accuracy']
acc_svc
# Out:
# 0.8090929154711984

# %% [markdown]
# ### Random forest classification

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_rf = RandomForestClassifier()

# %%
model_rf.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions_rf = model_rf.predict(X_test)

# %%
acc_rf = classification_report(y_test, predictions_rf, output_dict= True)['accuracy']
acc_rf
# Out:
# 0.9346722577797396

# %%
accuracy = pd.DataFrame(np.array([[acc_nn], [acc_svc],  [acc_rf]]) , index=['NN','SVC', 'RF'], columns=['Accuracy'])
accuracy
# Out:
#      Accuracy
# NN   0.813507
# SVC  0.809093
# RF   0.934672

# %%
accuracy.plot(kind='bar' , colormap='plasma')
plt.grid(axis='y' , color='green', linestyle='--', linewidth=0.5 )
